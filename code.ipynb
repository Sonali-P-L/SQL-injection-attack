# %% [markdown]
# **IMPORTS**

# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/sql-injection-dataset/sqliv2.csv
# /kaggle/input/sql-injection-dataset/sqli.csv
# /kaggle/input/sql-injection-dataset/SQLiV3.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from sklearn.metrics import accuracy_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn import tree
from tensorflow.keras import models, layers
import warnings

from sklearn.metrics import confusion_matrix, classification_report, f1_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import precision_recall_curve,precision_recall_fscore_support
import seaborn as sns
warnings.filterwarnings('ignore')

# %% [markdown]
# **LOADING AND PREPROCESSING DATASET**

# %%
path = '../input/sql-injection-dataset/'
df = pd.read_csv(path + "sqli.csv", encoding='utf-16')
print("Data Shape:", df.shape)
df.head(10)
# Out:
# Data Shape: (4200, 2)
#                     Sentence  Label
# 0                          a      1
# 1                        a'       1
# 2                      a' --      1
# 3            a' or 1 = 1; --      1
# 4                          @      1
# 5                          ?      1
# 6   ' and 1 = 0 )  union all      1
# 7              ? or 1 = 1 --      1
# 8  x' and userid is NULL; --      1
# 9   x' and email is NULL; --      1

# %%
X = df['Sentence']
y = df['Label']
print(X.shape, y.shape)
print("Dataset Input:", "\n", X.head(5))
print("Dataset Label:", "\n", y.head(5))
# Out:
# (4200,) (4200,)
# Dataset Input:
#  0                  a
# 1                a'
# 2              a' --
# 3    a' or 1 = 1; --
# 4                  @
# Name: Sentence, dtype: object
# Dataset Label:
#  0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Label, dtype: int64

# %%
import nltk
nltk.download('stopwords')
vectorizer = CountVectorizer(min_df = 2, max_df = 0.8, stop_words = stopwords.words('english'))
X = vectorizer.fit_transform(X.values.astype('U')).toarray()
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (3360, 4717)
# (3360,)
# (840, 4717)
# (840,)

# %%
f1_dict = {}
precision_dict = {}
recall_dict = {}
accuracy_dict = {}
train_accuracy = {}
validation_accuracy = {}
test_accuracy = {}

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
lr_clf = LogisticRegression()
y_pred_lr = lr_clf.fit(X_train, y_train)
y_pred = y_pred_lr.predict(X_test)
print(f"Accuracy of Logistic Regression on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of Logistic Regression on test set : {f1_score(y_pred, y_test)}")

# Updates model score to f1_dict
f1_dict["LogisticRegression"] = f1_score(y_pred, y_test)
precision_dict["LogisticRegression"] = precision_score(y_pred, y_test)
recall_dict["LogisticRegression"] = recall_score(y_pred, y_test)
accuracy_dict['LogisticRegression'] = accuracy_score(y_pred, y_test)
# Out:
# Accuracy of Logistic Regression on test set : 0.925
# F1 Score of Logistic Regression on test set : 0.851063829787234

# %%
from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras.wrappers.scikit_learn import KerasClassifier

input_dim = X_train.shape[1]  # Number of features

model = Sequential()
model.add(layers.Dense(20, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(10,  activation='tanh'))
model.add(layers.Dense(1024, activation='relu'))

model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
model.summary()

classifier_nn = model.fit(X_train,y_train,
                    epochs=10,
                    verbose=True,
                    validation_data=(X_test, y_test),
                    batch_size=15)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                94360
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              11264
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 110,955
# Trainable params: 108,907
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/10
# 224/224 [==============================] - 2s 5ms/step - loss: 0.2075 - accuracy: 0.9083 - val_loss: 0.6738 - val_accuracy: 0.7107
# Epoch 2/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0969 - accuracy: 0.9628 - val_loss: 0.2963 - val_accuracy: 0.8012
# Epoch 3/10
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0971 - accuracy: 0.9637 - val_loss: 0.0743 - val_accuracy: 0.9821
# Epoch 4/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0848 - accuracy: 0.9679 - val_loss: 0.0521 - val_accuracy: 0.9810
# Epoch 5/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0805 - accuracy: 0.9714 - val_loss: 0.0623 - val_accuracy: 0.9833
# Epoch 6/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0776 - accuracy: 0.9702 - val_loss: 0.1115 - val_accuracy: 0.9714
# Epoch 7/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0925 - accuracy: 0.9682 - val_loss: 0.0631 - val_accuracy: 0.9845
# Epoch 8/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0785 - accuracy: 0.9690 - val_loss: 0.0508 - val_accuracy: 0.9821
# Epoch 9/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0777 - accuracy: 0.9717 - val_loss: 0.0651 - val_accuracy: 0.9750
# Epoch 10/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0749 - accuracy: 0.9732 - val_loss: 0.0575 - val_accuracy: 0.9869

# %% [markdown]
# **RANDOM FOREST**

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)
y_pred = rf_clf.predict(X_test)
print(f"Accuracy of Random Forest on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of Random Forest on test set : {f1_score(y_pred, y_test)}")

# Updates model score to f1_dict
f1_dict["RandomForest"] = f1_score(y_pred, y_test)
precision_dict["RandomForest"] = precision_score(y_pred, y_test)
recall_dict["RandomForest"] = recall_score(y_pred, y_test)
accuracy_dict['RandomForest'] = accuracy_score(y_pred, y_test)
# Out:
# Accuracy of Random Forest on test set : 0.9202380952380952
# F1 Score of Random Forest on test set : 0.8788426763110307

# %%
from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras.wrappers.scikit_learn import KerasClassifier

input_dim = X_train.shape[1]  # Number of features

model = Sequential()
model.add(layers.Dense(20, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(10,  activation='tanh'))
model.add(layers.Dense(1024, activation='relu'))

model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
model.summary()

classifier_nn = model.fit(X_train,y_train,
                    epochs=10,
                    verbose=True,
                    validation_data=(X_test, y_test),
                    batch_size=15)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 20)                94360
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              11264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 110,955
# Trainable params: 108,907
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/10
# 224/224 [==============================] - 2s 5ms/step - loss: 0.2104 - accuracy: 0.9057 - val_loss: 0.6276 - val_accuracy: 0.7107
# Epoch 2/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0993 - accuracy: 0.9616 - val_loss: 0.4170 - val_accuracy: 0.7286
# Epoch 3/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0962 - accuracy: 0.9655 - val_loss: 0.0777 - val_accuracy: 0.9845
# Epoch 4/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0797 - accuracy: 0.9711 - val_loss: 0.0543 - val_accuracy: 0.9833
# Epoch 5/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0836 - accuracy: 0.9708 - val_loss: 0.1099 - val_accuracy: 0.9702
# Epoch 6/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0931 - accuracy: 0.9661 - val_loss: 0.0630 - val_accuracy: 0.9798
# Epoch 7/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0881 - accuracy: 0.9667 - val_loss: 0.0615 - val_accuracy: 0.9774
# Epoch 8/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0786 - accuracy: 0.9702 - val_loss: 0.0597 - val_accuracy: 0.9774
# Epoch 9/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0712 - accuracy: 0.9738 - val_loss: 0.0516 - val_accuracy: 0.9821
# Epoch 10/10
# 224/224 [==============================] - 1s 5ms/step - loss: 0.0761 - accuracy: 0.9720 - val_loss: 0.0602 - val_accuracy: 0.9774

# %% [markdown]
# **SUPPORT VECTOR MACHINES**

# %%
svm_clf = SVC(gamma = 'auto')
svm_clf.fit(X_train, y_train)
y_pred = svm_clf.predict(X_test)
print(f"Accuracy of SVM on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of SVM on test set : {f1_score(y_pred, y_test)}")

# Updates model score to f1_dict
f1_dict["SVM"] = f1_score(y_pred, y_test)
precision_dict["SVM"] = precision_score(y_pred, y_test)
recall_dict["SVM"] = recall_score(y_pred, y_test)
accuracy_dict['SVM'] = accuracy_score(y_pred, y_test)
# Out:
# Accuracy of SVM on test set : 0.7821428571428571
# F1 Score of SVM on test set : 0.396039603960396

# %%
from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras.wrappers.scikit_learn import KerasClassifier

input_dim = X_train.shape[1]  # Number of features

model = Sequential()
model.add(layers.Dense(20, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(10,  activation='tanh'))
model.add(layers.Dense(1024, activation='relu'))

model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
model.summary()

classifier_nn = model.fit(X_train,y_train,
                    epochs=10,
                    verbose=True,
                    validation_data=(X_test, y_test),
                    batch_size=15)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 20)                94360
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_10 (Dense)             (None, 1024)              11264
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 110,955
# Trainable params: 108,907
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/10
# 224/224 [==============================] - 2s 5ms/step - loss: 0.2217 - accuracy: 0.9039 - val_loss: 0.6601 - val_accuracy: 0.7107
# Epoch 2/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1102 - accuracy: 0.9631 - val_loss: 0.3447 - val_accuracy: 0.8000
# Epoch 3/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1001 - accuracy: 0.9583 - val_loss: 0.0747 - val_accuracy: 0.9821
# Epoch 4/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1008 - accuracy: 0.9616 - val_loss: 0.0645 - val_accuracy: 0.9774
# Epoch 5/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0823 - accuracy: 0.9685 - val_loss: 0.0546 - val_accuracy: 0.9821
# Epoch 6/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0863 - accuracy: 0.9682 - val_loss: 0.0734 - val_accuracy: 0.9750
# Epoch 7/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0813 - accuracy: 0.9702 - val_loss: 0.0831 - val_accuracy: 0.9726
# Epoch 8/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0721 - accuracy: 0.9711 - val_loss: 0.0468 - val_accuracy: 0.9857
# Epoch 9/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0747 - accuracy: 0.9726 - val_loss: 0.1127 - val_accuracy: 0.9274
# Epoch 10/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0766 - accuracy: 0.9714 - val_loss: 0.0725 - val_accuracy: 0.9774

# %% [markdown]
# **NAIVE BAYES**

# %%
nb_clf = GaussianNB()
nb_clf.fit(X_train, y_train)
y_pred = nb_clf.predict(X_test)
print(f"Accuracy of Naive Bayes on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of Naive Bayes on test set : {f1_score(y_pred, y_test)}")

# Updates model score to f1_dict
f1_dict["NaiveBayes"] = f1_score(y_pred, y_test)
precision_dict["NaiveBayes"] = precision_score(y_pred, y_test)
recall_dict["NaiveBayes"] = recall_score(y_pred, y_test)
accuracy_dict['NaiveBayes'] = accuracy_score(y_pred, y_test)
# Out:
# Accuracy of Naive Bayes on test set : 0.9821428571428571
# F1 Score of Naive Bayes on test set : 0.970059880239521

# %%
from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras.wrappers.scikit_learn import KerasClassifier

input_dim = X_train.shape[1]  # Number of features

model = Sequential()
model.add(layers.Dense(20, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(10,  activation='tanh'))
model.add(layers.Dense(1024, activation='relu'))

model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
model.summary()

classifier_nn = model.fit(X_train,y_train,
                    epochs=10,
                    verbose=True,
                    validation_data=(X_test, y_test),
                    batch_size=15)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 20)                94360
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_14 (Dense)             (None, 1024)              11264
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 110,955
# Trainable params: 108,907
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/10
# 224/224 [==============================] - 2s 5ms/step - loss: 0.2249 - accuracy: 0.9033 - val_loss: 0.6113 - val_accuracy: 0.7107
# Epoch 2/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1054 - accuracy: 0.9610 - val_loss: 0.2749 - val_accuracy: 0.8690
# Epoch 3/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0955 - accuracy: 0.9628 - val_loss: 0.0598 - val_accuracy: 0.9845
# Epoch 4/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0916 - accuracy: 0.9693 - val_loss: 0.0641 - val_accuracy: 0.9798
# Epoch 5/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0758 - accuracy: 0.9735 - val_loss: 0.0807 - val_accuracy: 0.9750
# Epoch 6/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0825 - accuracy: 0.9688 - val_loss: 0.0743 - val_accuracy: 0.9857
# Epoch 7/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0825 - accuracy: 0.9685 - val_loss: 0.0532 - val_accuracy: 0.9845
# Epoch 8/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0852 - accuracy: 0.9676 - val_loss: 0.0600 - val_accuracy: 0.9798
# Epoch 9/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0738 - accuracy: 0.9723 - val_loss: 0.0734 - val_accuracy: 0.9786
# Epoch 10/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0806 - accuracy: 0.9702 - val_loss: 0.0835 - val_accuracy: 0.9750

# %% [markdown]
# DECISION TREES

# %%
DT = tree.DecisionTreeClassifier()
DT.fit(X_train, y_train)
y_pred = DT.predict(X_test)
print(f"Accuracy of Naive Bayes on test set : {accuracy_score(y_pred, y_test)}")
print(f"F1 Score of Naive Bayes on test set : {f1_score(y_pred, y_test)}")

# Updates model score to f1_dict
f1_dict["DecisionTree"] = f1_score(y_pred, y_test)
precision_dict["DecisionTree"] = precision_score(y_pred, y_test)
recall_dict["DecisionTree"] = recall_score(y_pred, y_test)
accuracy_dict['DecisionTree'] = accuracy_score(y_pred, y_test)
# Out:
# Accuracy of Naive Bayes on test set : 0.85
# F1 Score of Naive Bayes on test set : 0.7941176470588235

# %%
from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras.wrappers.scikit_learn import KerasClassifier

input_dim = X_train.shape[1]  # Number of features

model = Sequential()
model.add(layers.Dense(20, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(10,  activation='tanh'))
model.add(layers.Dense(1024, activation='relu'))

model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
model.summary()

classifier_nn = model.fit(X_train,y_train,
                    epochs=10,
                    verbose=True,
                    validation_data=(X_test, y_test),
                    batch_size=15)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 20)                94360
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_18 (Dense)             (None, 1024)              11264
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 110,955
# Trainable params: 108,907
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/10
# 224/224 [==============================] - 2s 5ms/step - loss: 0.2210 - accuracy: 0.9009 - val_loss: 0.6310 - val_accuracy: 0.7107
# Epoch 2/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.1204 - accuracy: 0.9545 - val_loss: 0.3540 - val_accuracy: 0.7833
# Epoch 3/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0938 - accuracy: 0.9595 - val_loss: 0.0574 - val_accuracy: 0.9845
# Epoch 4/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0893 - accuracy: 0.9693 - val_loss: 0.0677 - val_accuracy: 0.9762
# Epoch 5/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0839 - accuracy: 0.9696 - val_loss: 0.0585 - val_accuracy: 0.9810
# Epoch 6/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0816 - accuracy: 0.9702 - val_loss: 0.0476 - val_accuracy: 0.9857
# Epoch 7/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0891 - accuracy: 0.9658 - val_loss: 0.0462 - val_accuracy: 0.9857
# Epoch 8/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0828 - accuracy: 0.9679 - val_loss: 0.0510 - val_accuracy: 0.9869
# Epoch 9/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0880 - accuracy: 0.9699 - val_loss: 0.0865 - val_accuracy: 0.9726
# Epoch 10/10
# 224/224 [==============================] - 1s 4ms/step - loss: 0.0877 - accuracy: 0.9682 - val_loss: 0.0581 - val_accuracy: 0.9798

# %% [markdown]
# FINAL PLOT FOR MODELS PERFORMANCE

# %%
keys2 = f1_dict, precision_dict, recall_dict, accuracy_dict
metrics = ['F1_Score', 'Precision', 'Recall', 'Accuracy']
data = pd.DataFrame(keys2)
data.index = metrics
data
# Out:
#            LogisticRegression  RandomForest       SVM  NaiveBayes  \
# F1_Score             0.851064      0.878843  0.396040    0.970060
# Precision            0.740741      1.000000  0.246914    1.000000
# Recall               1.000000      0.783871  1.000000    0.941860
# Accuracy             0.925000      0.920238  0.782143    0.982143
#
#            DecisionTree
# F1_Score       0.794118
# Precision      1.000000
# Recall         0.658537
# Accuracy       0.850000

# %%
result = data.plot(kind='bar', rot=0, figsize=(15, 7));
result.legend(bbox_to_anchor=(1, 1.02), loc='upper left');
